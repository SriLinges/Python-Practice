# %%
import pandas as pd 
dfr = pd.read_csv("nyc_weather.csv")
dfr
#dfr[:]
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-05-2016           20        -3        41                 30.57
# 1    1/18/2016           25         6        53                 29.83
# 2    1/22/2016           26         6        41                 30.21
# 3    1/23/2016           26        21        78                 29.77
# 4    1/24/2016           28        11        53                 29.92
# 5    1/14/2016           30        12        47                 29.95
# 6    1/17/2016           36        23        66                 29.78
# 7    1/28/2016           37        20        51                 29.90
# 8   01-01-2016           38        23        52                 30.03
# 9   01-08-2016           39        29        64                 30.20
# 10   1/27/2016           41        22        45                 30.03
# 11   1/15/2016           43        31        62                 29.82
# ...

# %%
dfr.shape
# Out:
# (15, 11)

# %%
r , c = dfr.shape
rows, columns = dfr.shape
rows
# Out:
# 15

# %%
columns
# Out:
# 11

# %%
r
# Out:
# 15

# %%
c
# Out:
# 11

# %%
dfr.head(5)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-05-2016           20        -3        41                 30.57
# 1   1/18/2016           25         6        53                 29.83
# 2   1/22/2016           26         6        41                 30.21
# 3   1/23/2016           26        21        78                 29.77
# 4   1/24/2016           28        11        53                 29.92
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0               10           5.0               0           0       NaN
# 1                9          12.0               T           2      Snow
# 2                9           NaN            0.01           3      Snow
# 3                1          16.0            2.31           8  Fog-Snow
# 4                8           6.0               T           3      Snow
#
#    WindDirDegrees
# 0             333
# 1             293
# 2              34
# 3              42
# 4             327

# %%
dfr.tail(5)
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 10   1/27/2016           41        22        45                 30.03
# 11   1/15/2016           43        31        62                 29.82
# 12  01-09-2016           44        38        77                 30.16
# 13   1/16/2016           47        37        70                 29.52
# 14  01-10-2016           50        46        71                 29.59
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 10               10           7.0               T           3   Rain
# 11                9           5.0               T           2    NaN
# 12                9           8.0               T           8   Rain
# 13                8           7.0            0.24           7   Rain
# 14                4           NaN             1.8           7   Rain
#
#     WindDirDegrees
# 10             311
# 11             101
# 12              76
# 13             340
# 14             109

# %%
dfr[1:4]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 1  1/18/2016           25         6        53                 29.83
# 2  1/22/2016           26         6        41                 30.21
# 3  1/23/2016           26        21        78                 29.77
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 1                9          12.0               T           2      Snow
# 2                9           NaN            0.01           3      Snow
# 3                1          16.0            2.31           8  Fog-Snow
#
#    WindDirDegrees
# 1             293
# 2              34
# 3              42

# %%
dfr.EST
# Out:
# 0     01-05-2016
# 1      1/18/2016
# 2      1/22/2016
# 3      1/23/2016
# 4      1/24/2016
# 5      1/14/2016
# 6      1/17/2016
# 7      1/28/2016
# 8     01-01-2016
# 9     01-08-2016
# 10     1/27/2016
# 11     1/15/2016
# 12    01-09-2016
# 13     1/16/2016
# 14    01-10-2016
# Name: EST, dtype: object

# %%
dfr['EST']
# Out:
# 0     01-05-2016
# 1      1/18/2016
# 2      1/22/2016
# 3      1/23/2016
# 4      1/24/2016
# 5      1/14/2016
# 6      1/17/2016
# 7      1/28/2016
# 8     01-01-2016
# 9     01-08-2016
# 10     1/27/2016
# 11     1/15/2016
# 12    01-09-2016
# 13     1/16/2016
# 14    01-10-2016
# Name: EST, dtype: object

# %%
dfr[['EST','Temperature']]
# Out:
#            EST  Temperature
# 0   01-05-2016           20
# 1    1/18/2016           25
# 2    1/22/2016           26
# 3    1/23/2016           26
# 4    1/24/2016           28
# 5    1/14/2016           30
# 6    1/17/2016           36
# 7    1/28/2016           37
# 8   01-01-2016           38
# 9   01-08-2016           39
# 10   1/27/2016           41
# 11   1/15/2016           43
# 12  01-09-2016           44
# 13   1/16/2016           47
# 14  01-10-2016           50

# %%
dfr.Temperature.max()
#dfr['Temperature'].max()
# Out:
# 50

# %%
dfr.Temperature.min()
#dfr['Temperature'].min()
# Out:
# 20

# %%
dfr.Temperature.mean()
#dfr['Temperature'].mean()
# Out:
# 35.333333333333336
